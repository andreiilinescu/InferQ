# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from utils import *

# %%
data = pd.read_csv('circuits_data400000.csv')
print(data.shape)
# Out:
# C:\Users\aadik\AppData\Local\Temp\ipykernel_11724\3481451919.py:1: DtypeWarning: Columns (3,5,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('circuits_data400000.csv')
# (400000, 86)

# %% [markdown]
# # Distribution
#
# Looking at the dsitrubition of sparsity and entropy as well as qubit count and depth

# %%
# Let us get all the columns
# related to execution time
time_columns = get_time_columns(data)
print(time_columns)
# Out:
# ['automatic_execution_time', 'density_matrix_execution_time', 'extended_stabilizer_execution_time', 'matrix_product_state_execution_time', 'stabilizer_execution_time', 'statevector_execution_time', 'statevector_saved_execution_time', 'unitary_execution_time']

# %%
features = ['num_qubits', 'statevector_saved_entropy', 'statevector_saved_sparsity']

make_histogram_grid(data, features, "Relevant static features")

# %% [markdown]
# # Entropy

# %%
bin_labels, fastest_counts = plot_entropy_bin_times(data, time_columns, bins = 10)
# Out:
# c:\Users\aadik\InferQ\analysis\utils.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entropy_data['entropy_bin'] = pd.cut(entropy_data['statevector_saved_entropy'], bins=entropy_bins)

# %%
plot_bin_times_percentage(bin_labels, fastest_counts, time_columns, label="Entropy")

# %% [markdown]
# # Sparsity

# %%
sbin_labels, sfastest_counts = plot_sparsity_bin_times(data, time_columns, bins =10)
# Out:
# c:\Users\aadik\InferQ\analysis\utils.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sparsity_data['sparsity_bin'] = pd.cut(sparsity_data['statevector_saved_sparsity'], bins=sparsity_bins)

# %%
plot_bin_times_percentage(sbin_labels, sfastest_counts, time_columns, label="Sparsity")

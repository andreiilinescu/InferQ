# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

data = pd.read_csv('circuits_data400000.csv')
print(data.columns)

METHODS = [
    # "statevector_saved",
    "statevector",
    # "stabilizer",
    "density_matrix",
    "matrix_product_state",
    "extended_stabilizer",
    "unitary",
    # "automatic"
]
